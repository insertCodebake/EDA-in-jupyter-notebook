# %%
import pandas as pd
import numpy as np
import seaborn as sb
import matplotlib.pyplot as mt
# %matplotlib inline

# %%
data=pd.read_csv(r"C:\Users\Jagadeesh\Downloads\expected_ctc.csv")
df=pd.DataFrame(data)
df.head(n=5)
# Out:
#    IDX  Applicant_ID  Total_Experience  Total_Experience_in_field_applied  \
# 0    1         22753                 0                                  0
# 1    2         51087                23                                 14
# 2    3         38413                21                                 12
# 3    4         11501                15                                  8
# 4    5         58941                10                                  5
#
#        Department               Role   Industry Organization      Designation  \
# 0             NaN                NaN        NaN          NaN              NaN
# 1              HR         Consultant  Analytics            H               HR
# 2  Top Management         Consultant   Training            J              NaN
# 3         Banking  Financial Analyst   Aviation            F               HR
# 4           Sales    Project Manager  Insurance            E  Medical Officer
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25000 entries, 0 to 24999
# Data columns (total 29 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   IDX                                25000 non-null  int64
#  1   Applicant_ID                       25000 non-null  int64
#  2   Total_Experience                   25000 non-null  int64
#  3   Total_Experience_in_field_applied  25000 non-null  int64
#  4   Department                         22222 non-null  object
#  5   Role                               24037 non-null  object
#  6   Industry                           24092 non-null  object
#  7   Organization                       24092 non-null  object
#  8   Designation                        21871 non-null  object
#  9   Education                          25000 non-null  object
#  10  Graduation_Specialization          18820 non-null  object
# ...

# %%
df.isnull()
# Out:
#          IDX  Applicant_ID  Total_Experience  \
# 0      False         False             False
# 1      False         False             False
# 2      False         False             False
# 3      False         False             False
# 4      False         False             False
# ...      ...           ...               ...
# 24995  False         False             False
# 24996  False         False             False
# 24997  False         False             False
# 24998  False         False             False
# 24999  False         False             False
#
#        Total_Experience_in_field_applied  Department   Role  Industry  \
# 0                                  False        True   True      True
# 1                                  False       False  False     False
# 2                                  False       False  False     False
# 3                                  False       False  False     False
# ...

# %%
df.shape
# Out:
# (25000, 29)

# %%
df.isna().sum()
# Out:
# IDX                                      0
# Applicant_ID                             0
# Total_Experience                         0
# Total_Experience_in_field_applied        0
# Department                            2778
# Role                                   963
# Industry                               908
# Organization                           908
# Designation                           3129
# Education                                0
# Graduation_Specialization             6180
# University_Grad                       6180
# Passing_Year_Of_Graduation            6180
# PG_Specialization                     7692
# University_PG                         7692
# Passing_Year_Of_PG                    7692
# PHD_Specialization                   11881
# University_PHD                       11881
# Passing_Year_Of_PHD                  11881
# Curent_Location                          0
# Preferred_location                       0
# Current_CTC                              0
# ...

# %%
df.describe()
# Out:
#                 IDX  Applicant_ID  Total_Experience  \
# count  25000.000000  25000.000000      25000.000000
# mean   12500.500000  34993.240080         12.493080
# std     7217.022701  14390.271591          7.471398
# min        1.000000  10000.000000          0.000000
# 25%     6250.750000  22563.750000          6.000000
# 50%    12500.500000  34974.500000         12.000000
# 75%    18750.250000  47419.000000         19.000000
# max    25000.000000  60000.000000         25.000000
#
#        Total_Experience_in_field_applied  Passing_Year_Of_Graduation  \
# count                       25000.000000                18820.000000
# mean                            6.258200                 2002.193624
# std                             5.819513                    8.316640
# min                             0.000000                 1986.000000
# 25%                             1.000000                 1996.000000
# 50%                             5.000000                 2002.000000
# ...

# %%
df.corr()
# Out:
#                                         IDX  Applicant_ID  Total_Experience  \
# IDX                                1.000000      0.006398         -0.006057
# Applicant_ID                       0.006398      1.000000         -0.007831
# Total_Experience                  -0.006057     -0.007831          1.000000
# Total_Experience_in_field_applied -0.007226     -0.005316          0.645135
# Passing_Year_Of_Graduation         0.003669      0.005731         -0.902931
# Passing_Year_Of_PG                 0.007296      0.006927         -0.634718
# Passing_Year_Of_PHD                0.004170      0.012610         -1.000000
# Current_CTC                       -0.007226     -0.011724          0.846476
# No_Of_Companies_worked            -0.002094     -0.005943          0.398135
# Number_of_Publications             0.003233     -0.006884         -0.000494
# Certifications                     0.002833     -0.004531         -0.001130
# ...

# %%
df.describe(include=['object'])
# Out:
#        Department    Role  Industry Organization Designation Education  \
# count       22222   24037     24092        24092       21871     25000
# unique         12      24        11           16          18         4
# top     Marketing  Others  Training            M          HR        PG
# freq         2379    2248      2237         1574        1648      6326
#
#        Graduation_Specialization University_Grad PG_Specialization  \
# count                      18820           18820             17308
# unique                        11              13                11
# top                    Chemistry     Bhubaneswar       Mathematics
# freq                        1785            1510              1800
#
#        University_PG PHD_Specialization University_PHD Curent_Location  \
# count          17308              13119          13119           25000
# unique            13                 11             13              15
# ...

# %%
df.hist()
# Out:
# array([[<AxesSubplot:title={'center':'IDX'}>,
#         <AxesSubplot:title={'center':'Applicant_ID'}>,
#         <AxesSubplot:title={'center':'Total_Experience'}>,
#         <AxesSubplot:title={'center':'Total_Experience_in_field_applied'}>],
#        [<AxesSubplot:title={'center':'Passing_Year_Of_Graduation'}>,
#         <AxesSubplot:title={'center':'Passing_Year_Of_PG'}>,
#         <AxesSubplot:title={'center':'Passing_Year_Of_PHD'}>,
#         <AxesSubplot:title={'center':'Current_CTC'}>],
#        [<AxesSubplot:title={'center':'No_Of_Companies_worked'}>,
#         <AxesSubplot:title={'center':'Number_of_Publications'}>,
#         <AxesSubplot:title={'center':'Certifications'}>,
#         <AxesSubplot:title={'center':'International_degree_any'}>],
#        [<AxesSubplot:title={'center':'Expected_CTC'}>, <AxesSubplot:>,
#         <AxesSubplot:>, <AxesSubplot:>]], dtype=object)

# %%
df.iloc[:,2:8].hist(bins=200)
# Out:
# array([[<AxesSubplot:title={'center':'Total_Experience'}>,
#         <AxesSubplot:title={'center':'Total_Experience_in_field_applied'}>]],
#       dtype=object)

# %%
df.nunique()
# Out:
# IDX                                  25000
# Applicant_ID                         19766
# Total_Experience                        26
# Total_Experience_in_field_applied       26
# Department                              12
# Role                                    24
# Industry                                11
# Organization                            16
# Designation                             18
# Education                                4
# Graduation_Specialization               11
# University_Grad                         13
# Passing_Year_Of_Graduation              35
# PG_Specialization                       11
# University_PG                           13
# Passing_Year_Of_PG                      36
# PHD_Specialization                      11
# University_PHD                          13
# Passing_Year_Of_PHD                     26
# Curent_Location                         15
# Preferred_location                      15
# Current_CTC                          23992
# ...

# %%
df.groupby(["Applicant_ID","Current_CTC","Expected_CTC"]).size()
# Out:
# Applicant_ID  Current_CTC  Expected_CTC
# 10000         2029016      2536270         1
# 10001         3366415      4335942         1
# 10004         2572782      3215977         1
# 10006         1389237      1597622         1
# 10007         1053242      1279057         1
#                                           ..
# 59995         1816088      2088501         1
# 59996         1466388      1906304         1
#               2367469      3077709         1
#               2697570      3371962         1
# 60000         1725124      2063248         1
# Length: 25000, dtype: int64

# %%
df.hist(["Current_CTC"])
# Out:
# array([[<AxesSubplot:title={'center':'Current_CTC'}>]], dtype=object)

# %%
mt.figure(figsize=(15,9))
sb.heatmap(df.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
sb.barplot(x='Total_Experience',y='Current_CTC',data=df)
# Out:
# <AxesSubplot:xlabel='Total_Experience', ylabel='Current_CTC'>

# %%
sb.barplot(x='Total_Experience',y='Expected_CTC',data=df)
# Out:
# <AxesSubplot:xlabel='Total_Experience', ylabel='Expected_CTC'>

# %%
sb.barplot(x="No_Of_Companies_worked",y="Current_CTC",data=data)
# Out:
# <AxesSubplot:xlabel='No_Of_Companies_worked', ylabel='Current_CTC'>

# %%
df.nunique()
# Out:
# IDX                                  25000
# Applicant_ID                         19766
# Total_Experience                        26
# Total_Experience_in_field_applied       26
# Department                              12
# Role                                    24
# Industry                                11
# Organization                            16
# Designation                             18
# Education                                4
# Graduation_Specialization               11
# University_Grad                         13
# Passing_Year_Of_Graduation              35
# PG_Specialization                       11
# University_PG                           13
# Passing_Year_Of_PG                      36
# PHD_Specialization                      11
# University_PHD                          13
# Passing_Year_Of_PHD                     26
# Curent_Location                         15
# Preferred_location                      15
# Current_CTC                          23992
# ...

# %%
df['Department'].unique()
# Out:
# array([nan, 'HR', 'Top Management', 'Banking', 'Sales', 'Engineering',
#        'Others', 'Analytics/BI', 'Education', 'Marketing', 'Healthcare',
#        'IT-Software', 'Accounts'], dtype=object)

# %%
sb.barplot(x="Education",y="Current_CTC",data=data)
# Out:
# <AxesSubplot:xlabel='Education', ylabel='Current_CTC'>

# %% [markdown]
# # Obersavtion
# * The CTC of Doctrate holders are high compared to other degree holders
